# %% [markdown]
# 7/29 (Tue)
#
# ---
#
# # Frequency Analysis of Converted Codes in L2 Japanese Pragmatics Instruction Research
#
# To synthesize target, treatment, learner, outcome measure features, this notebook calculates frequency/proportion of identified codes.
# This notebook converts the original coding results to more abstract codes to count frequencies.

# %% [markdown]
# The following code block imports Python packages.

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# The following code block defines a global variable of the path to data directry.

# %%
DATA_DIR = Path.cwd().parents[1] / "data"

# %% [markdown]
# ### Utility Functions
#
# The following code block defines a function to search top key of hierarchical dictionray from a value.

# %%
def find_top_key(d: dict[str, dict|list|str], target: str) -> str|None:
    for key, value in d.items():
        if isinstance(value, dict):
            # 再帰的に探す
            found = find_top_key(value, target)
            if found:  # 下層から見つかったら、上位層のkeyを返す
                return key
        elif isinstance(value, list):
            if target in value:
                return key # 下層から見つかったら、上位層のkeyを返す
        else:
            if value == target:
                return key
    return None # 見つからない場合はNone

# %% [markdown]
# The following code block defines a function to remove redundant commas from multi-value cells.

# %%
def remove_redundant_commas(multi_val: str) -> str:
    if pd.isna(multi_val):
        return multi_val

    cleaned_val_list = []
    for val in multi_val.split(", "):
        if val == "":
            continue
        if val == ",":
            continue
        cleaned_val_list.append(val)

    return ", ".join(cleaned_val_list)

# %% [markdown]
# ---
#
# ## 1. Data Loading & Preprocess

# %% [markdown]
# ### 1.1. Data Loading
#
# The following code block loads the table of coding results (data/external/coding_result_ver_1.tsv).

# %%
tsv_path = DATA_DIR / "external/coding_result_ver_1.tsv"

df_coding_result_raw = pd.read_table(tsv_path, sep="\t", skiprows=[0, 1], header=0)

# %% [markdown]
# The following code block loads code hierarchy dictionary (data/external/code_hierarchy_ver_1.json).

# %%
with open(DATA_DIR / "external/code_hierarchy_ver_1.json") as f:
    code_hierarcy = json.load(f)

# %% [markdown]
# ### 1.2. Preprocessing
#
# The following code block converts a group column by assigning either explicit or implicit code.

# %%
mask_explicit = df_coding_result_raw["Meta Pragmatic Information"]

# assign explicit/implicit codes to experimental design studies.
mask_experimental = df_coding_result_raw["Group"].str.contains("Experimental")


df_coding_result_raw.loc[mask_experimental & mask_explicit, "Group"] \
    = df_coding_result_raw.loc[mask_experimental & mask_explicit, "Group"].str.replace("Experimental", "Explicit")
df_coding_result_raw.loc[mask_experimental & ~mask_explicit, "Group"] \
    = df_coding_result_raw.loc[mask_experimental & ~mask_explicit, "Group"].str.replace("Experimental", "Implicit")

# assign explicit/implicit codes to pre/posttest design studies.
mask_prepost_design = df_coding_result_raw["Group"].isna()

df_coding_result_raw.loc[mask_prepost_design & mask_explicit, "Group"] = "Explicit"
df_coding_result_raw.loc[mask_prepost_design & ~mask_explicit, "Group"] = "Implicit"

# %% [markdown]
# The following code block sets Study ID, Authors, Year, and Group as multiple indices.

# %%
multiple_indices = []

prev_study_id = ""
prev_authors = ""
prev_year = ""
for idx in df_coding_result_raw.index:
    cur_study_id = df_coding_result_raw.at[idx, "Study ID"]
    if pd.isna(cur_study_id):
        cur_study_id = prev_study_id

    cur_authors = df_coding_result_raw.at[idx, "Authors"]
    if pd.isna(cur_authors):
        cur_authors = prev_authors

    cur_year = df_coding_result_raw.at[idx, "Year"]
    if pd.isna(cur_year):
        cur_year = prev_year

    cur_group = df_coding_result_raw.at[idx, "Group"]

    multiple_indices.append((cur_study_id, cur_authors, cur_year, cur_group))

    prev_study_id = cur_study_id
    prev_authors = cur_authors
    prev_year = cur_year

multiple_indices = pd.MultiIndex.from_tuples(multiple_indices, names=["Study ID", "Authors", "Year", "Group"])

df_coding_result = df_coding_result_raw.drop(["Study ID", "Paper IDs", "Authors", "Year", "Group"], axis=1)
df_coding_result.index = multiple_indices

# %% [markdown]
# The following code blocks apply the following conversions:
# 1. Class year level to proficiency levels
#     - (1st Year → Novice; 2nd Year → Intermediate; 3rd Year → Intermediate; 4th Year → Advanced)
# 2. *a soo desu ka* to *soo desu ka*
# 3. remove fill-in-the-blank tests from production task
#     - If fill-in-the-blank is the only task used as production practice, set False in the Production column
# 4. remove Metacognitive Strategy Questionnaire from outcome measures and results
#     - See comments on Google Spreadsheet.

# %%
# Class Year Lvl → Prof. Lvl
converter = {
    "1st Year": "Novice",
    "2nd Year": "Intermediate",
    "3rd Year": "Intermediate",
    "4th Year": "Advanced"
}

for class_year_level, proficiency in converter.items():
    mask_prof_is_nan = df_coding_result["Proficiency Level"].isna()
    mask_class_year_level = df_coding_result["Class Year Level"].str.contains(class_year_level)
    mask = mask_prof_is_nan & mask_class_year_level # Prof. Lvl が NA で，指定するクラスレベルの行を取り出すマスク

    df_coding_result.loc[mask, "Proficiency Level"] = proficiency

# %%
# a soo desu ka → soo desu ka
converted_linguistic_items_col = df_coding_result["Linguistic Items"].str.replace("a soo desu ka", "soo desu ka")
df_coding_result.loc[:, "Linguistic Items"] = converted_linguistic_items_col

# %%
# remove fill-in-the-blank in Production Task col.
converted_production_task_col = df_coding_result["Production Task"].str.replace(
    "Audio-visual Fill-in-the-blank Task", ""
)
converted_production_task_col = converted_production_task_col.str.replace(
    "Fill-in-the-blank Task", ""
)
df_coding_result.loc[:, "Production Task"] = converted_production_task_col

mask_no_production_task = converted_production_task_col == ""
mask_production_is_true = df_coding_result["Production"]
mask = mask_no_production_task & mask_production_is_true

df_coding_result.loc[mask, "Production"] = False
df_coding_result.loc[mask_no_production_task, "Production Task"] = np.nan

# %%
# remove metacognitive strategy questionnaire
df_coding_result.loc[9, "Outcome Measure 1"] = np.nan

result_col_1_start = "Within-group Results"
result_col_2_end = "Evidence of Potential Moderators/Reasons for Variety in Between-group Results"
df_coding_result.loc[9, result_col_1_start:result_col_2_end] = np.nan

# %% [markdown]
# ### 1.3. Brief Summarization of Table
#
# This subsection briefly summarizes the converted table to show research settings (i.e., country, institution, N participants, L1, proficiency levels), pragmatic targets, treatment type (i.e., explicit vs. implicit), outcome measures, Analysis (i.e., Qual. vs. Quan.), and Results (e.g., positive, negative, & no impact) for within-group and between-group results, respectively.

# %% [markdown]
# #### 1.3.1. Within-Ggroup Results
#
# The following code block drops unrelated index.

# %%
mask_control = df_coding_result.index.get_level_values(3).str.contains("Control")
df_within_res = df_coding_result[~mask_control].copy(deep=True)

# %% [markdown]
# The following code blocks summarize the coding results.

# %%
# --- generate the context column, which contains values, like "US university".
country = df_within_res.loc[:, "Country"].copy(deep=True)
institution = df_within_res.loc[:, "Institution"].copy(deep=True)
context_col = country + " " + institution
context_col = context_col.ffill()

# %%
# --- generate the participant column, which contains values, like "English L1 Novice Learners (N = 13)". ---
## convert L1 columns
l1 = df_within_res.loc[:, "L1"].copy(deep=True)
l1[l1.isna()] = "Not Specified"
l1[l1.str.contains(",")] = "Mixed"
l1 = l1.apply(lambda lang: f"{lang} L1")

## convert N participant columns
n_participant = df_within_res.loc[:, "N Participants"].copy(deep=True)
n_participant = n_participant.apply(lambda n: f"(n={n})")

proficiency = df_within_res.loc[:, "Proficiency Level"].copy(deep=True)

## join L1, proficiency, and sample size information
participant_col = l1 + " " + proficiency + " " + n_participant

# %%
# --- generate the abstract pragmatic target column ---
pragmatic_target_col = df_within_res.loc[:, "Pragmatic Target"].copy(deep=True)

## get abstract codes
particle_list = code_hierarcy["Target Feature"]["Pragmatic Target"]["Particle"]
pragmatic_target_col = pragmatic_target_col.apply(lambda target: target if target not in particle_list else "Particle")

## fill NaN
pragmatic_target_col = pragmatic_target_col.ffill()

# %%
# --- generate the outcome measures column ---
outcome_measures = df_within_res.loc[:, "Outcome Measure 1":"Outcome Measure 4"].copy(deep=True)

## get abstract codes
outcome_measures = outcome_measures.map(
    lambda measure: find_top_key(code_hierarcy["Assessment Feature"], measure), na_action="ignore"
)

## join all outcome measures
outcome_measures_col = outcome_measures.loc[:, "Outcome Measure 1"].str.cat(
    [
        outcome_measures.loc[:, "Outcome Measure 2"],
        outcome_measures.loc[:, "Outcome Measure 3"],
        outcome_measures.loc[:, "Outcome Measure 4"]
    ],
    sep=", ",
    na_rep=""
)

## fill NaN
outcome_measures_col.loc[outcome_measures_col == ", , , "] = np.nan
outcome_measures_col = outcome_measures_col.ffill()
outcome_measures_col = outcome_measures_col.apply(remove_redundant_commas)

# %%
# --- generate the data column ---
analysis = df_within_res.loc[:, "Qualitative Analysis":"Quantitative Report Type"]

# judge mixed, qual. or quan
analysis_col = pd.Series(np.full(len(analysis), ""), index=analysis.index)
analysis_col[analysis["Qualitative Analysis"] & analysis["Quantitative Analysis"]] = "Mixed"
analysis_col[analysis["Qualitative Analysis"] & ~analysis["Quantitative Analysis"]] = "Qual"
analysis_col[~analysis["Qualitative Analysis"] & analysis["Quantitative Analysis"]] = "Quan"

# judge whether stats. tests were used
analysis_col[analysis["Quantitative Report Type"].str.contains("Statistical Test", na=False)] += "+"

# fill NaN
analysis_col.loc[analysis_col == ""] = np.nan
analysis_col = analysis_col.ffill()

# %%
# --- generate the result column ---
target_columns = [
    "Within-group Results",
    "Within-group Results.1",
    "Within-group Results.2",
    "Within-group Results.3",
]
results = df_within_res.loc[:, target_columns].copy(deep=True)

result_col = results["Within-group Results"].str.cat(
    [
        results["Within-group Results.1"],
        results["Within-group Results.2"],
        results["Within-group Results.3"],
    ],
    sep=", ",
    na_rep=""
)

result_col.loc[result_col == ", , , "] = np.nan
result_col = result_col.bfill()
result_col = result_col.apply(remove_redundant_commas)

# %%
# --- add generated columns and summarize brief within-group results ---

df_within_res.loc[:, "Context"] = context_col
df_within_res.loc[:, "Participant"] = participant_col
df_within_res.loc[:, "Target"] = pragmatic_target_col
df_within_res.loc[:, "Outcome Measures"] = outcome_measures_col
df_within_res.loc[:, "Analysis"] = analysis_col
df_within_res.loc[:, "Results"] = result_col

df_within_res.loc[:, "Context":"Results"].sort_index(level=1)
# Out:
#                                                                                                                     Context  \
# Study ID Authors                                Year                   Group
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                               US University
# 1.0      Gyogi                                  2016                   Implicit                               UK University
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit                               US University
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Fall                          US University
#                                                                        Explicit Full                          US University
#                                                                        Explicit Spring                        US University
# 15.0     Iwai                                   2010                   Explicit                               US University
#                                                                        Explicit Expanded                      US University
# 4.0      Kakegawa                               2009                   Explicit                               US University
# 14.0     Katayama                               2012                   Explicit                           Canada University
#                                                                        Implicit                           Canada University
# 13.0     Kim                                    2016                   Explicit                               US University
#                                                                        Explicit Expanded                      US University
# 7.0      Narita, Narita                         2009, 2012             Implicit                               US University
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                               US University
#                                                                        Implicit                               US University
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                               US University
#                                                                        Explicit Expanded                      US University
# 11.0     Tsujihara                              2023                   Explicit                               US University
# 12.0     Tsujihara                              2023                   Explicit                               US University
# 3.0      Utashiro & Kawai                       2009                   Explicit           Japan University, Language School
# 2.0      Yoshimi                                2001                   Explicit                               US University
#
#                                                                                                                      Participant  \
# Study ID Authors                                Year                   Group
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit           English L1 Novice, Intermediate (n=22)
# 1.0      Gyogi                                  2016                   Implicit                     Mixed L1 Intermediate (n=14)
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit             Not Specified L1 Intermediate (n=14)
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Fall                      Mixed L1 Novice (n=14)
#                                                                        Explicit Full                     English L1 Novice (n=6)
#                                                                        Explicit Spring                    Mixed L1 Novice (n=12)
# 15.0     Iwai                                   2010                   Explicit                   Not Specified L1 Novice (n=14)
#                                                                        Explicit Expanded          Not Specified L1 Novice (n=15)
# 4.0      Kakegawa                               2009                   Explicit                     Mixed L1 Intermediate (n=11)
# 14.0     Katayama                               2012                   Explicit                     Mixed L1 Intermediate (n=21)
#                                                                        Implicit                     Mixed L1 Intermediate (n=19)
# 13.0     Kim                                    2016                   Explicit           Mixed L1 Intermediate, Advanced (n=32)
#                                                                        Explicit Expanded  Mixed L1 Intermediate, Advanced (n=33)
# 7.0      Narita, Narita                         2009, 2012             Implicit                   English L1 Intermediate (n=22)
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                           Mixed L1 Novice (n=13)
#                                                                        Implicit                           Mixed L1 Novice (n=14)
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                     Mixed L1 Intermediate (n=22)
#                                                                        Explicit Expanded            Mixed L1 Intermediate (n=24)
# 11.0     Tsujihara                              2023                   Explicit                      Mixed L1 Intermediate (n=6)
# 12.0     Tsujihara                              2023                   Explicit                         Mixed L1 Advanced (n=12)
# 3.0      Utashiro & Kawai                       2009                   Explicit           Mixed L1 Intermediate, Advanced (n=24)
# 2.0      Yoshimi                                2001                   Explicit                      Mixed L1 Intermediate (n=5)
#
#                                                                                                              Target  \
# Study ID Authors                                Year                   Group
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                          Speech Act
# 1.0      Gyogi                                  2016                   Implicit                            Particle
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit                            Particle
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Fall                       Particle
#                                                                        Explicit Full                       Particle
#                                                                        Explicit Spring                     Particle
# 15.0     Iwai                                   2010                   Explicit                          Small Talk
#                                                                        Explicit Expanded                 Small Talk
# 4.0      Kakegawa                               2009                   Explicit                            Particle
# 14.0     Katayama                               2012                   Explicit                            Particle
#                                                                        Implicit                            Particle
# 13.0     Kim                                    2016                   Explicit                            Particle
#                                                                        Explicit Expanded                   Particle
# 7.0      Narita, Narita                         2009, 2012             Implicit           Hearsay Evidential Marker
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                          Speech Act
#                                                                        Implicit                          Speech Act
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                          Speech Act
#                                                                        Explicit Expanded                 Speech Act
# 11.0     Tsujihara                              2023                   Explicit                          Speech Act
# 12.0     Tsujihara                              2023                   Explicit                          Speech Act
# 3.0      Utashiro & Kawai                       2009                   Explicit                     Reactive Tokens
# 2.0      Yoshimi                                2001                   Explicit                            Particle
#
#                                                                                                                            Outcome Measures  \
# Study ID Authors                                Year                   Group
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                                  Production
# 1.0      Gyogi                                  2016                   Implicit                                 Production, Decision Making
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit           Comprehension/Perception, Comprehension/Percep...
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Fall                               Comprehension/Perception
#                                                                        Explicit Full                               Comprehension/Perception
#                                                                        Explicit Spring                             Comprehension/Perception
# 15.0     Iwai                                   2010                   Explicit                                                  Production
#                                                                        Explicit Expanded                                         Production
# 4.0      Kakegawa                               2009                   Explicit                                                  Production
# 14.0     Katayama                               2012                   Explicit                                                  Production
#                                                                        Implicit                                                  Production
# 13.0     Kim                                    2016                   Explicit                                    Comprehension/Perception
#                                                                        Explicit Expanded                           Comprehension/Perception
# 7.0      Narita, Narita                         2009, 2012             Implicit           Comprehension/Perception, Comprehension/Percep...
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                        Comprehension/Perception, Production
#                                                                        Implicit                        Comprehension/Perception, Production
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Production, Production, Production, Comprehens...
#                                                                        Explicit Expanded  Production, Production, Production, Comprehens...
# 11.0     Tsujihara                              2023                   Explicit                                 Production, Decision Making
# 12.0     Tsujihara                              2023                   Explicit                Production, Decision Making, Self-Evaluation
# 3.0      Utashiro & Kawai                       2009                   Explicit                        Production, Comprehension/Perception
# 2.0      Yoshimi                                2001                   Explicit                                                  Production
#
#                                                                                          Analysis  \
# Study ID Authors                                Year                   Group
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit             Mixed
# 1.0      Gyogi                                  2016                   Implicit              Qual
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit             Mixed
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Fall        Mixed
#                                                                        Explicit Full        Mixed
#                                                                        Explicit Spring      Mixed
# 15.0     Iwai                                   2010                   Explicit             Mixed
#                                                                        Explicit Expanded    Mixed
# 4.0      Kakegawa                               2009                   Explicit             Mixed
# 14.0     Katayama                               2012                   Explicit             Quan+
#                                                                        Implicit             Quan+
# 13.0     Kim                                    2016                   Explicit             Quan+
#                                                                        Explicit Expanded    Quan+
# 7.0      Narita, Narita                         2009, 2012             Implicit            Mixed+
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit            Mixed+
#                                                                        Implicit            Mixed+
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit            Mixed+
#                                                                        Explicit Expanded   Mixed+
# 11.0     Tsujihara                              2023                   Explicit             Mixed
# 12.0     Tsujihara                              2023                   Explicit             Mixed
# 3.0      Utashiro & Kawai                       2009                   Explicit             Quan+
# 2.0      Yoshimi                                2001                   Explicit             Mixed
#
#                                                                                                                          Results
# Study ID Authors                                Year                   Group
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                         Positive
# 1.0      Gyogi                                  2016                   Implicit                               Positive, Positive
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit           Positive, Positive, Positive, Positive
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Fall                                    Positive
#                                                                        Explicit Full                                    Positive
#                                                                        Explicit Spring                                  Positive
# 15.0     Iwai                                   2010                   Explicit                                         Positive
#                                                                        Explicit Expanded                                Positive
# 4.0      Kakegawa                               2009                   Explicit                                         Positive
# 14.0     Katayama                               2012                   Explicit                                         Positive
#                                                                        Implicit                                         Positive
# 13.0     Kim                                    2016                   Explicit                                         Positive
#                                                                        Explicit Expanded                                Positive
# 7.0      Narita, Narita                         2009, 2012             Implicit                     Positive, Positive, Positive
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                             No Impact, No Impact
#                                                                        Implicit                             No Impact, No Impact
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Positive, Positive, Positive, Positive
#                                                                        Explicit Expanded  Positive, Positive, Positive, Positive
# 11.0     Tsujihara                              2023                   Explicit                               Positive, Positive
# 12.0     Tsujihara                              2023                   Explicit                    No Impact, Positive, Positive
# 3.0      Utashiro & Kawai                       2009                   Explicit                               Positive, Positive
# 2.0      Yoshimi                                2001                   Explicit                                         Positive

# %% [markdown]
# The table suggests that almost all studies showed positive impacts of pragmatic instruction regardless of learning targets, proficiency levels, instruction types, and outcome measures.
# However, two studies, Tateyama (1998, 2001) and Tsujihara (2023) showed that the changes of pragmatic performance were not observed.
# Both studies focused on speech act.
# In addition, Tsujihara reported the positive impacts of instruction in the measures of descision making and self-evaluation.
# Thus, the learning of Japanese speech act production might be relatively more difficult than other pragmatic targets.
# Meanwhile, other studies targeting speech act (e.g., Ishihara, 2005, 2006, 2007; Tateyama 2006, 2007, 2008, 2009; Tsujihara, 2023) showed positive results in speech act production.
#
# To furhter analyze those differences in a more detailed manner, the following code block shows the table of treatment features.

# %%
target_study_id = [6, 9, 11, 5, 12]

treatment_feature_columns = [
    "Intervention Length",
    "Meta Pragmatic Information",
    "Input",
    "Input Enhancement",
    "Inductive Consciousness-Raising",
    "Deductive Consciousness-Raising",
    "Production",
    "Journal Writing/ Self-reflection",
    "Feedback",
    "Discussion"
]

df_within_res.loc[target_study_id, ["Results", "Outcome Measures"] + treatment_feature_columns].style.apply(
    lambda col: ["background-color: #d65f5f" if flag else "background-color: #5fba7d" for flag in col],
    subset=treatment_feature_columns[1:]
)
# Out:
# <style type="text/css">
# #T_d1efd_row0_col3, #T_d1efd_row0_col4, #T_d1efd_row0_col6, #T_d1efd_row0_col8, #T_d1efd_row0_col9, #T_d1efd_row0_col10, #T_d1efd_row0_col11, #T_d1efd_row1_col3, #T_d1efd_row1_col4, #T_d1efd_row1_col8, #T_d1efd_row2_col3, #T_d1efd_row2_col4, #T_d1efd_row2_col6, #T_d1efd_row2_col8, #T_d1efd_row2_col9, #T_d1efd_row2_col10, #T_d1efd_row3_col3, #T_d1efd_row3_col4, #T_d1efd_row3_col7, #T_d1efd_row3_col8, #T_d1efd_row3_col9, #T_d1efd_row3_col10, #T_d1efd_row3_col11, #T_d1efd_row4_col3, #T_d1efd_row4_col4, #T_d1efd_row4_col8, #T_d1efd_row4_col9, #T_d1efd_row4_col11, #T_d1efd_row5_col4, #T_d1efd_row5_col6, #T_d1efd_row5_col8, #T_d1efd_row5_col9, #T_d1efd_row6_col3, #T_d1efd_row6_col4, #T_d1efd_row6_col7, #T_d1efd_row6_col8, #T_d1efd_row6_col9, #T_d1efd_row6_col10, #T_d1efd_row6_col11 {
#   background-color: #d65f5f;
# }
# #T_d1efd_row0_col5, #T_d1efd_row0_col7, #T_d1efd_row1_col5, #T_d1efd_row1_col6, #T_d1efd_row1_col7, #T_d1efd_row1_col9, #T_d1efd_row1_col10, #T_d1efd_row1_col11, #T_d1efd_row2_col5, #T_d1efd_row2_col7, #T_d1efd_row2_col11, #T_d1efd_row3_col5, #T_d1efd_row3_col6, #T_d1efd_row4_col5, #T_d1efd_row4_col6, #T_d1efd_row4_col7, #T_d1efd_row4_col10, #T_d1efd_row5_col3, #T_d1efd_row5_col5, #T_d1efd_row5_col7, #T_d1efd_row5_col10, #T_d1efd_row5_col11, #T_d1efd_row6_col5, #T_d1efd_row6_col6 {
#   background-color: #5fba7d;
# }
# </style>
# <table id="T_d1efd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1efd_level0_col0" class="col_heading level0 col0" >Results</th>
#       <th id="T_d1efd_level0_col1" class="col_heading level0 col1" >Outcome Measures</th>
#       <th id="T_d1efd_level0_col2" class="col_heading level0 col2" >Intervention Length</th>
#       <th id="T_d1efd_level0_col3" class="col_heading level0 col3" >Meta Pragmatic Information</th>
#       <th id="T_d1efd_level0_col4" class="col_heading level0 col4" >Input</th>
#       <th id="T_d1efd_level0_col5" class="col_heading level0 col5" >Input Enhancement</th>
#       <th id="T_d1efd_level0_col6" class="col_heading level0 col6" >Inductive Consciousness-Raising</th>
#       <th id="T_d1efd_level0_col7" class="col_heading level0 col7" >Deductive Consciousness-Raising</th>
#       <th id="T_d1efd_level0_col8" class="col_heading level0 col8" >Production</th>
#       <th id="T_d1efd_level0_col9" class="col_heading level0 col9" >Journal Writing/ Self-reflection</th>
#       <th id="T_d1efd_level0_col10" class="col_heading level0 col10" >Feedback</th>
#       <th id="T_d1efd_level0_col11" class="col_heading level0 col11" >Discussion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Study ID</th>
#       <th class="index_name level1" >Authors</th>
#       <th class="index_name level2" >Year</th>
#       <th class="index_name level3" >Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1efd_level0_row0" class="row_heading level0 row0" rowspan="2">6.000000</th>
#       <th id="T_d1efd_level1_row0" class="row_heading level1 row0" rowspan="2">Tateyama, Tateyama, Tateyama, Tateyama</th>
#       <th id="T_d1efd_level2_row0" class="row_heading level2 row0" rowspan="2">2006, 2007, 2008, 2009</th>
#       <th id="T_d1efd_level3_row0" class="row_heading level3 row0" >Explicit</th>
#       <td id="T_d1efd_row0_col0" class="data row0 col0" >Positive, Positive, Positive, Positive</td>
#       <td id="T_d1efd_row0_col1" class="data row0 col1" >Production, Production, Production, Comprehension/Perception</td>
#       <td id="T_d1efd_row0_col2" class="data row0 col2" >Medium Treatments</td>
#       <td id="T_d1efd_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_d1efd_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_d1efd_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_d1efd_row0_col6" class="data row0 col6" >True</td>
#       <td id="T_d1efd_row0_col7" class="data row0 col7" >False</td>
#       <td id="T_d1efd_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_d1efd_row0_col9" class="data row0 col9" >True</td>
#       <td id="T_d1efd_row0_col10" class="data row0 col10" >True</td>
#       <td id="T_d1efd_row0_col11" class="data row0 col11" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1efd_level3_row1" class="row_heading level3 row1" >Explicit Expanded</th>
#       <td id="T_d1efd_row1_col0" class="data row1 col0" >Positive, Positive, Positive, Positive</td>
#       <td id="T_d1efd_row1_col1" class="data row1 col1" >Production, Production, Production, Comprehension/Perception</td>
#       <td id="T_d1efd_row1_col2" class="data row1 col2" >Medium Treatments</td>
#       <td id="T_d1efd_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_d1efd_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_d1efd_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_d1efd_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_d1efd_row1_col7" class="data row1 col7" >False</td>
#       <td id="T_d1efd_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_d1efd_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_d1efd_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_d1efd_row1_col11" class="data row1 col11" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1efd_level0_row2" class="row_heading level0 row2" >9.000000</th>
#       <th id="T_d1efd_level1_row2" class="row_heading level1 row2" >Cohen & Ishihara, Ishihara, Ishihara</th>
#       <th id="T_d1efd_level2_row2" class="row_heading level2 row2" >2005, 2006, 2007</th>
#       <th id="T_d1efd_level3_row2" class="row_heading level3 row2" >Explicit</th>
#       <td id="T_d1efd_row2_col0" class="data row2 col0" >Positive</td>
#       <td id="T_d1efd_row2_col1" class="data row2 col1" >Production</td>
#       <td id="T_d1efd_row2_col2" class="data row2 col2" >Medium Treatments</td>
#       <td id="T_d1efd_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_d1efd_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_d1efd_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_d1efd_row2_col6" class="data row2 col6" >True</td>
#       <td id="T_d1efd_row2_col7" class="data row2 col7" >False</td>
#       <td id="T_d1efd_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_d1efd_row2_col9" class="data row2 col9" >True</td>
#       <td id="T_d1efd_row2_col10" class="data row2 col10" >True</td>
#       <td id="T_d1efd_row2_col11" class="data row2 col11" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1efd_level0_row3" class="row_heading level0 row3" >11.000000</th>
#       <th id="T_d1efd_level1_row3" class="row_heading level1 row3" >Tsujihara</th>
#       <th id="T_d1efd_level2_row3" class="row_heading level2 row3" >2023</th>
#       <th id="T_d1efd_level3_row3" class="row_heading level3 row3" >Explicit</th>
#       <td id="T_d1efd_row3_col0" class="data row3 col0" >Positive, Positive</td>
#       <td id="T_d1efd_row3_col1" class="data row3 col1" >Production, Decision Making</td>
#       <td id="T_d1efd_row3_col2" class="data row3 col2" >Medium Treatments</td>
#       <td id="T_d1efd_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_d1efd_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_d1efd_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_d1efd_row3_col6" class="data row3 col6" >False</td>
#       <td id="T_d1efd_row3_col7" class="data row3 col7" >True</td>
#       <td id="T_d1efd_row3_col8" class="data row3 col8" >True</td>
#       <

# %% [markdown]
# One of the difference in studies was the instruction types (i.e., explicit vs. implict).
# To facilitate the ability to understand the appropriateness of speech act use, it might be better to provide meta-pragmatic information.
#
# Another difference in studies was the opportunity of consciousness-raising activities.
# Theoretically, consciousness-raising activities can enhance learners' awareness of the link between forms and contexts, ultimately facilitate the ability to understand the appropriateness of speech act use or change learners' decision-making processes.
# Thus, non-existance of consciousness-raising activities in the explicit group in Tateyama (1998, 2001) failed to improve their comprehension/perception ability, while the explicit group in Tsujihara (2023) could improve their decision making ability.
# However, the regular-explicit group in Tateyama (2006, 2007, 2008, 2009) showed positive changes of comprehension/perception measures, it would be necessary to more detailed comparison between those studies.
#
# Moreover, regarding the production, all groups received the opportunity of production practices, the table did not suggest any potential factors affect the within-group result differences.
# Thus, it might be better to inspect what production tasks during instruction and tests were used in those studies.
#
# To further compare those studies, the following table shows more detailed informaton of instructio and outcome measure materials.

# %%
target_study_id = [6, 9, 11, 5, 12]

material_columns = [
    "Production Task",
    "Outcome Measure 1",
    "Outcome Measure 2",
    "Outcome Measure 3",
    "Outcome Measure 4"
]

df_within_res.loc[target_study_id, ["Results", "Outcome Measures"] + material_columns]
# Out:
#                                                                                                                          Results  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Positive, Positive, Positive, Positive
#                                                                        Explicit Expanded  Positive, Positive, Positive, Positive
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                         Positive
# 11.0     Tsujihara                              2023                   Explicit                               Positive, Positive
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                             No Impact, No Impact
#                                                                        Implicit                             No Impact, No Impact
# 12.0     Tsujihara                              2023                   Explicit                    No Impact, Positive, Positive
#
#                                                                                                                            Outcome Measures  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Production, Production, Production, Comprehens...
#                                                                        Explicit Expanded  Production, Production, Production, Comprehens...
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                                  Production
# 11.0     Tsujihara                              2023                   Explicit                                 Production, Decision Making
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                        Comprehension/Perception, Production
#                                                                        Implicit                        Comprehension/Perception, Production
# 12.0     Tsujihara                              2023                   Explicit                Production, Decision Making, Self-Evaluation
#
#                                                                                                                             Production Task  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Oral Role-plays with an L2, Oral Role-plays wi...
#                                                                        Explicit Expanded                         Oral Role-plays with an L2
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                   Discourse Completion Task
# 11.0     Tsujihara                              2023                   Explicit                                   Discourse Completion Task
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                                   Discourse Completion Task
#                                                                        Implicit                                   Discourse Completion Task
# 12.0     Tsujihara                              2023                   Explicit           Discourse Completion Task, Oral Role-plays wit...
#
#                                                                                                   Outcome Measure 1  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Discourse Completion Task
#                                                                        Explicit Expanded                        NaN
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                 NaN
# 11.0     Tsujihara                              2023                   Explicit           Discourse Completion Task
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit               Multiple-Choice Tests
#                                                                        Implicit                                 NaN
# 12.0     Tsujihara                              2023                   Explicit           Discourse Completion Task
#
#                                                                                                        Outcome Measure 2  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Oral Discourse Completion Task
#                                                                        Explicit Expanded                             NaN
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit           Oral Discourse Completion Task
# 11.0     Tsujihara                              2023                   Explicit                  Retrospective Interview
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                               Role-plays
#                                                                        Implicit                                      NaN
# 12.0     Tsujihara                              2023                   Explicit                  Retrospective Interview
#
#                                                                                          Outcome Measure 3  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                 Role-plays
#                                                                        Explicit Expanded               NaN
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                        NaN
# 11.0     Tsujihara                              2023                   Explicit                        NaN
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                        NaN
#                                                                        Implicit                        NaN
# 12.0     Tsujihara                              2023                   Explicit            Self-evaluation
#
#                                                                                                Outcome Measure 4
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Acceptability Judgment
#                                                                        Explicit Expanded                     NaN
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                              NaN
# 11.0     Tsujihara                              2023                   Explicit                              NaN
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                              NaN
#                                                                        Implicit                              NaN
# 12.0     Tsujihara                              2023                   Explicit                              NaN

# %% [markdown]
# In the comparison between Tateyama (1998, 2001) and Tateyama (2006, 2007, 2008, 2009) studies, the table suggests the gaps of modality between production practice task and outcome measures.
# More specifically, in the explicit group in Tateyama (2006, 2007, 2008, 2009), learners engaged in oral production practices and took oral production tests.
# On the other hand, the explicit group in Tateyama (1998, 2001) engaged in DCTs as practice, while the test was role-plays.
# This modality gap might be one reason of no-impact results in Tateyama (1998, 2001).
#
# ※ ただ，Ishihara の study も練習とテストに modality gap がある．一方で，こちらは DCT → Oral DCT なので，modality と task design の両方が違うことが1つの原因か？
# ※ 加えて，Tateyama (1998, 2001) は習熟度が低い学生が対象となっている．一方で，Ishihara は intermediate level learners が対象なので，この proficiency の差も関係するかも．
#
# However, in the explicit group in Tsujihara (2023), there was no modality gap between practice and assessment.
# Given another explicit group in Tsujihara (2023) engaged in the same/similar instructions and assessments, it might be necessary to qualitatively compare those groups.
#
# ※ Tsujihara の study については，天井効果が考えられる．上級学習者を対象としており，かつ，最初から多用な形式を利用できるようになっている．
# ※ 加えて，SCOBAs があることでパフォーマンスが若干良くなっていること，pilot study に比べ練習の機会が少なかったことから，internalization のレベルには達していないが，verbalization のレベルには達しているかも．

# %%
material_columns = [
    "Production Task",
    "Outcome Measure 1",
    "Outcome Measure 2",
    "Outcome Measure 3",
    "Outcome Measure 4"
]

df_within_res.loc[:, ["Results", "Outcome Measures"] + material_columns]
# Out:
#                                                                                                                          Results  \
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                               Positive, Positive
# 2.0      Yoshimi                                2001                   Explicit                                         Positive
# 3.0      Utashiro & Kawai                       2009                   Explicit                               Positive, Positive
# 4.0      Kakegawa                               2009                   Explicit                                         Positive
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                             No Impact, No Impact
#                                                                        Implicit                             No Impact, No Impact
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Positive, Positive, Positive, Positive
#                                                                        Explicit Expanded  Positive, Positive, Positive, Positive
# 7.0      Narita, Narita                         2009, 2012             Implicit                     Positive, Positive, Positive
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit           Positive, Positive, Positive, Positive
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                         Positive
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                                    Positive
#                                                                        Explicit Fall                                    Positive
#                                                                        Explicit Spring                                  Positive
# 11.0     Tsujihara                              2023                   Explicit                               Positive, Positive
# 12.0     Tsujihara                              2023                   Explicit                    No Impact, Positive, Positive
# 13.0     Kim                                    2016                   Explicit Expanded                                Positive
#                                                                        Explicit                                         Positive
# 14.0     Katayama                               2012                   Explicit                                         Positive
#                                                                        Implicit                                         Positive
# 15.0     Iwai                                   2010                   Explicit                                         Positive
#                                                                        Explicit Expanded                                Positive
#
#                                                                                                                            Outcome Measures  \
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                                 Production, Decision Making
# 2.0      Yoshimi                                2001                   Explicit                                                  Production
# 3.0      Utashiro & Kawai                       2009                   Explicit                        Production, Comprehension/Perception
# 4.0      Kakegawa                               2009                   Explicit                                                  Production
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                        Comprehension/Perception, Production
#                                                                        Implicit                        Comprehension/Perception, Production
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Production, Production, Production, Comprehens...
#                                                                        Explicit Expanded  Production, Production, Production, Comprehens...
# 7.0      Narita, Narita                         2009, 2012             Implicit           Comprehension/Perception, Comprehension/Percep...
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit           Comprehension/Perception, Comprehension/Percep...
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                                  Production
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                               Comprehension/Perception
#                                                                        Explicit Fall                               Comprehension/Perception
#                                                                        Explicit Spring                             Comprehension/Perception
# 11.0     Tsujihara                              2023                   Explicit                                 Production, Decision Making
# 12.0     Tsujihara                              2023                   Explicit                Production, Decision Making, Self-Evaluation
# 13.0     Kim                                    2016                   Explicit Expanded                           Comprehension/Perception
#                                                                        Explicit                                    Comprehension/Perception
# 14.0     Katayama                               2012                   Explicit                                                  Production
#                                                                        Implicit                                                  Production
# 15.0     Iwai                                   2010                   Explicit                                                  Production
#                                                                        Explicit Expanded                                         Production
#
#                                                                                                                             Production Task  \
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                                            Text Translation
# 2.0      Yoshimi                                2001                   Explicit                          Oral Story Telling Task with an L1
# 3.0      Utashiro & Kawai                       2009                   Explicit                              , Oral Role-plays with an L2,
# 4.0      Kakegawa                               2009                   Explicit                                        Email Correspondence
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                                   Discourse Completion Task
#                                                                        Implicit                                   Discourse Completion Task
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Oral Role-plays with an L2, Oral Role-plays wi...
#                                                                        Explicit Expanded                         Oral Role-plays with an L2
# 7.0      Narita, Narita                         2009, 2012             Implicit                                                         NaN
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit           Oral Translation, Oral Unscripted Interaction ...
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                   Discourse Completion Task
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full      Oral Role-plays with an L2, Oral Unscripted In...
#                                                                        Explicit Fall      Oral Role-plays with an L2, Oral Unscripted In...
#                                                                        Explicit Spring    Oral Role-plays with an L2, Oral Unscripted In...
# 11.0     Tsujihara                              2023                   Explicit                                   Discourse Completion Task
# 12.0     Tsujihara                              2023                   Explicit           Discourse Completion Task, Oral Role-plays wit...
# 13.0     Kim                                    2016                   Explicit Expanded                                                NaN
#                                                                        Explicit                                                         NaN
# 14.0     Katayama                               2012                   Explicit                                                         NaN
#                                                                        Implicit                                                         NaN
# 15.0     Iwai                                   2010                   Explicit             Oral Role-plays with an L2, Small Talk with L2s
#                                                                        Explicit Expanded    Oral Role-plays with an L2, Small Talk with L2s
#
#                                                                                                                  Outcome Measure 1  \
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                              Text Translation Task
# 2.0      Yoshimi                                2001                   Explicit                             Oral Storytelling Task
# 3.0      Utashiro & Kawai                       2009                   Explicit                         Oral Proficiency Interview
# 4.0      Kakegawa                               2009                   Explicit                               Email Correspondence
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                              Multiple-Choice Tests
#                                                                        Implicit                                                NaN
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                          Discourse Completion Task
#                                                                        Explicit Expanded                                       NaN
# 7.0      Narita, Narita                         2009, 2012             Implicit                              Multiple-Choice Tests
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit           Metapragmatic Knowledge Explanation Task
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                                NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                        Acceptability Judgment
#                                                                        Explicit Fall                                           NaN
#                                                                        Explicit Spring                                         NaN
# 11.0     Tsujihara                              2023                   Explicit                          Discourse Completion Task
# 12.0     Tsujihara                              2023                   Explicit                          Discourse Completion Task
# 13.0     Kim                                    2016                   Explicit Expanded                     Multiple-Choice Tests
#                                                                        Explicit                                                NaN
# 14.0     Katayama                               2012                   Explicit                          Discourse Completion Task
#                                                                        Implicit                                                NaN
# 15.0     Iwai                                   2010                   Explicit                       Oral Spontaneous Interaction
#                                                                        Explicit Expanded                                       NaN
#
#                                                                                                         Outcome Measure 2  \
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                   Retrospective Interview
# 2.0      Yoshimi                                2001                   Explicit                                       NaN
# 3.0      Utashiro & Kawai                       2009                   Explicit           Video-based Meaning Asking Task
# 4.0      Kakegawa                               2009                   Explicit                                       NaN
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                                Role-plays
#                                                                        Implicit                                       NaN
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit            Oral Discourse Completion Task
#                                                                        Explicit Expanded                              NaN
# 7.0      Narita, Narita                         2009, 2012             Implicit                     Multiple-Choice Tests
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit                     Multiple-Choice Tests
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit            Oral Discourse Completion Task
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                                  NaN
#                                                                        Explicit Fall                                  NaN
#                                                                        Explicit Spring                                NaN
# 11.0     Tsujihara                              2023                   Explicit                   Retrospective Interview
# 12.0     Tsujihara                              2023                   Explicit                   Retrospective Interview
# 13.0     Kim                                    2016                   Explicit Expanded                              NaN
#                                                                        Explicit                                       NaN
# 14.0     Katayama                               2012                   Explicit                                       NaN
#                                                                        Implicit                                       NaN
# 15.0     Iwai                                   2010                   Explicit                                       NaN
#                                                                        Explicit Expanded                              NaN
#
#                                                                                                        Outcome Measure 3  \
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                                      NaN
# 2.0      Yoshimi                                2001                   Explicit                                      NaN
# 3.0      Utashiro & Kawai                       2009                   Explicit                                      NaN
# 4.0      Kakegawa                               2009                   Explicit                                      NaN
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                                      NaN
#                                                                        Implicit                                      NaN
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                               Role-plays
#                                                                        Explicit Expanded                             NaN
# 7.0      Narita, Narita                         2009, 2012             Implicit           Oral Discourse Completion Task
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit             Oral Spontaneous Interaction
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                                      NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                                 NaN
#                                                                        Explicit Fall                                 NaN
#                                                                        Explicit Spring                               NaN
# 11.0     Tsujihara                              2023                   Explicit                                      NaN
# 12.0     Tsujihara                              2023                   Explicit                          Self-evaluation
# 13.0     Kim                                    2016                   Explicit Expanded                             NaN
#                                                                        Explicit                                      NaN
# 14.0     Katayama                               2012                   Explicit                                      NaN
#                                                                        Implicit                                      NaN
# 15.0     Iwai                                   2010                   Explicit                                      NaN
#                                                                        Explicit Expanded                             NaN
#
#                                                                                                Outcome Measure 4
# Study ID Authors                                Year                   Group
# 1.0      Gyogi                                  2016                   Implicit                              NaN
# 2.0      Yoshimi                                2001                   Explicit                              NaN
# 3.0      Utashiro & Kawai                       2009                   Explicit                              NaN
# 4.0      Kakegawa                               2009                   Explicit                              NaN
# 5.0      Tateyama, Tateyama                     1998, 2001             Explicit                              NaN
#                                                                        Implicit                              NaN
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Acceptability Judgment
#                                                                        Explicit Expanded                     NaN
# 7.0      Narita, Narita                         2009, 2012             Implicit                              NaN
# 8.0      Hoshi, Hoshi                           2017, 2022             Explicit                  Self-evaluation
# 9.0      Cohen & Ishihara, Ishihara, Ishihara   2005, 2006, 2007       Explicit                              NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                         NaN
#                                                                        Explicit Fall                         NaN
#                                                                        Explicit Spring                       NaN
# 11.0     Tsujihara                              2023                   Explicit                              NaN
# 12.0     Tsujihara                              2023                   Explicit                              NaN
# 13.0     Kim                                    2016                   Explicit Expanded                     NaN
#                                                                        Explicit                              NaN
# 14.0     Katayama                               2012                   Explicit                              NaN
#                                                                        Implicit                              NaN
# 15.0     Iwai                                   2010                   Explicit                              NaN
#                                                                        Explicit Expanded                     NaN

# %% [markdown]
# Utashiro & Kawai は，reactive tokens を対象としており，practice と outcome measures の task にギャップあり (Role-plays vs. OPIs)
# ↔ 一方で，伸びが見られることから speech act の方が難しいかも...？

# %% [markdown]
# #### 1.3.2. Between-Group Results
#
# This subsection briefly summarizes the coding results of between-group comparisons.
# More specifically, I separate studies which compare experimental and control groups and two instructions and summarize each result.

# %% [markdown]
# The following code block drops unrelated index (i.e., pretest-posttest design studies.)

# %%
mask = df_coding_result["Study Design"].ffill() == "Quasi-Experimental Design"

df_between_res = df_coding_result[mask].copy(deep=True)

# %% [markdown]
# The following code block summarizes the coded between-group results.

# %%
# --- generate the result column ---
target_columns = [
    "Between-group Results",
    "Between-group Results.1",
    "Between-group Results.2",
    "Between-group Results.3",
]
results = df_between_res.loc[:, target_columns].copy(deep=True)

result_col = results["Between-group Results"].str.cat(
    [
        results["Between-group Results.1"],
        results["Between-group Results.2"],
        results["Between-group Results.3"],
    ],
    sep=", ",
    na_rep=""
)

result_col.loc[result_col == ", , , "] = np.nan
result_col = result_col.apply(remove_redundant_commas)

# %% [markdown]
# The following code block (1) merges the summarized columns of within-group table (i.e., Participant, Target Outcome, Measures, Analysis) and (2) adds the above Result column to the between-group table

# %%
df_between_res = pd.merge(
    df_between_res, df_within_res.loc[:, "Participant":"Analysis"], how="left", left_index=True, right_index=True
)

df_between_res.loc[:, "Results"] = result_col

# %% [markdown]
# ***Experimental vs. Control Group***
#
# The following code block shows the experimental vs. control group comparison results.

# %%
exp_vs_cont_study_id = [2.0, 7.0, 8.0, 10.0, 15.0]
exceptional_groups = [
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Explicit Full"),
    (15.0, "Iwai", "2010", "Explicit Expanded")
]

df_between_res.loc[exp_vs_cont_study_id, "Participant":"Results"].drop(exceptional_groups)
# Out:
#                                                                                            Participant  \
# Study ID Authors                Year             Group
# 2.0      Yoshimi                2001             Explicit                  Mixed L1 Intermediate (n=5)
#                                                  Control                                           NaN
# 7.0      Narita, Narita         2009, 2012       Implicit               English L1 Intermediate (n=22)
#                                                  Control                                           NaN
# 8.0      Hoshi, Hoshi           2017, 2022       Explicit         Not Specified L1 Intermediate (n=14)
#                                                  Control                                           NaN
# 10.0     Ishida, Ishida, Ishida 2007, 2009, 2009 Explicit Fall                  Mixed L1 Novice (n=14)
#                                                  Control Fall                                      NaN
#                                                  Explicit Spring                Mixed L1 Novice (n=12)
#                                                  Control Spring                                    NaN
# 15.0     Iwai                   2010             Explicit               Not Specified L1 Novice (n=14)
#                                                  Control                                           NaN
#
#                                                                                      Target  \
# Study ID Authors                Year             Group
# 2.0      Yoshimi                2001             Explicit                          Particle
#                                                  Control                                NaN
# 7.0      Narita, Narita         2009, 2012       Implicit         Hearsay Evidential Marker
#                                                  Control                                NaN
# 8.0      Hoshi, Hoshi           2017, 2022       Explicit                          Particle
#                                                  Control                                NaN
# 10.0     Ishida, Ishida, Ishida 2007, 2009, 2009 Explicit Fall                     Particle
#                                                  Control Fall                           NaN
#                                                  Explicit Spring                   Particle
#                                                  Control Spring                         NaN
# 15.0     Iwai                   2010             Explicit                        Small Talk
#                                                  Control                                NaN
#
#                                                                                                    Outcome Measures  \
# Study ID Authors                Year             Group
# 2.0      Yoshimi                2001             Explicit                                                Production
#                                                  Control                                                        NaN
# 7.0      Narita, Narita         2009, 2012       Implicit         Comprehension/Perception, Comprehension/Percep...
#                                                  Control                                                        NaN
# 8.0      Hoshi, Hoshi           2017, 2022       Explicit         Comprehension/Perception, Comprehension/Percep...
#                                                  Control                                                        NaN
# 10.0     Ishida, Ishida, Ishida 2007, 2009, 2009 Explicit Fall                             Comprehension/Perception
#                                                  Control Fall                                                   NaN
#                                                  Explicit Spring                           Comprehension/Perception
#                                                  Control Spring                                                 NaN
# 15.0     Iwai                   2010             Explicit                                                Production
#                                                  Control                                                        NaN
#
#                                                                  Analysis  \
# Study ID Authors                Year             Group
# 2.0      Yoshimi                2001             Explicit           Mixed
#                                                  Control              NaN
# 7.0      Narita, Narita         2009, 2012       Implicit          Mixed+
#                                                  Control              NaN
# 8.0      Hoshi, Hoshi           2017, 2022       Explicit           Mixed
#                                                  Control              NaN
# 10.0     Ishida, Ishida, Ishida 2007, 2009, 2009 Explicit Fall      Mixed
#                                                  Control Fall         NaN
#                                                  Explicit Spring    Mixed
#                                                  Control Spring       NaN
# 15.0     Iwai                   2010             Explicit           Mixed
#                                                  Control              NaN
#
#                                                                                                  Results
# Study ID Authors                Year             Group
# 2.0      Yoshimi                2001             Explicit                                       Positive
#                                                  Control                                             NaN
# 7.0      Narita, Narita         2009, 2012       Implicit                   Positive, Positive, Positive
#                                                  Control                                             NaN
# 8.0      Hoshi, Hoshi           2017, 2022       Explicit         Positive, Positive, Positive, Positive
#                                                  Control                                             NaN
# 10.0     Ishida, Ishida, Ishida 2007, 2009, 2009 Explicit Fall                                  Positive
#                                                  Control Fall                                        NaN
#                                                  Explicit Spring                                Positive
#                                                  Control Spring                                      NaN
# 15.0     Iwai                   2010             Explicit                                       Positive
#                                                  Control                                             NaN

# %% [markdown]
# The table sugggests that pragmatic instruction is generally effective, aligning with previous review studies.

# %% [markdown]
# ***Two Instruction Comparison***
#
# The following code block shows the explicit vs. implicit comparison results.

# %%
exp_vs_imp_study_id = [5.0, 14.0]

df_between_res.loc[exp_vs_imp_study_id, "Participant":"Results"]
# Out:
#                                                                   Participant  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit        Mixed L1 Novice (n=13)
#                                        Implicit        Mixed L1 Novice (n=14)
# 14.0     Katayama           2012       Explicit  Mixed L1 Intermediate (n=21)
#                                        Implicit  Mixed L1 Intermediate (n=19)
#
#                                                      Target  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit  Speech Act
#                                        Implicit  Speech Act
# 14.0     Katayama           2012       Explicit    Particle
#                                        Implicit    Particle
#
#                                                                      Outcome Measures  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit  Comprehension/Perception, Production
#                                        Implicit  Comprehension/Perception, Production
# 14.0     Katayama           2012       Explicit                            Production
#                                        Implicit                            Production
#
#                                                 Analysis              Results
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit   Mixed+  No Impact, Negative
#                                        Implicit   Mixed+                  NaN
# 14.0     Katayama           2012       Explicit    Quan+            No Impact
#                                        Implicit    Quan+                  NaN

# %% [markdown]
# The table generally suggest that there are no difference between explicit and implicit groups, which contradicts previous pragmatic instruction reviews.
# Moreover, Tateyama (1998, 2001) showed that the implicit group outperformed the explicit group production tests in terms of production measures.
#
# To further explore those studies, the following table shows the detailed instructional features.

# %%
exp_vs_imp_study_id = [5.0, 14.0]

treatment_feature_columns = [
    "Intervention Length",
    "Meta Pragmatic Information",
    "Input",
    "Input Enhancement",
    "Inductive Consciousness-Raising",
    "Deductive Consciousness-Raising",
    "Production",
    "Journal Writing/ Self-reflection",
    "Feedback",
    "Discussion"
]

df_between_res.loc[
    exp_vs_imp_study_id, 
    ["Proficiency Level", "Results", "Outcome Measures"] + treatment_feature_columns
].style.apply(
    lambda col: ["background-color: #d65f5f" if flag else "background-color: #5fba7d" for flag in col],
    subset=treatment_feature_columns[1:]
)
# Out:
# <style type="text/css">
# #T_d6661_row0_col4, #T_d6661_row0_col5, #T_d6661_row0_col9, #T_d6661_row0_col10, #T_d6661_row0_col12, #T_d6661_row1_col5, #T_d6661_row1_col7, #T_d6661_row1_col9, #T_d6661_row1_col10, #T_d6661_row2_col4, #T_d6661_row2_col5, #T_d6661_row2_col6, #T_d6661_row3_col5, #T_d6661_row3_col6, #T_d6661_row3_col7 {
#   background-color: #d65f5f;
# }
# #T_d6661_row0_col6, #T_d6661_row0_col7, #T_d6661_row0_col8, #T_d6661_row0_col11, #T_d6661_row1_col4, #T_d6661_row1_col6, #T_d6661_row1_col8, #T_d6661_row1_col11, #T_d6661_row1_col12, #T_d6661_row2_col7, #T_d6661_row2_col8, #T_d6661_row2_col9, #T_d6661_row2_col10, #T_d6661_row2_col11, #T_d6661_row2_col12, #T_d6661_row3_col4, #T_d6661_row3_col8, #T_d6661_row3_col9, #T_d6661_row3_col10, #T_d6661_row3_col11, #T_d6661_row3_col12 {
#   background-color: #5fba7d;
# }
# </style>
# <table id="T_d6661">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6661_level0_col0" class="col_heading level0 col0" >Proficiency Level</th>
#       <th id="T_d6661_level0_col1" class="col_heading level0 col1" >Results</th>
#       <th id="T_d6661_level0_col2" class="col_heading level0 col2" >Outcome Measures</th>
#       <th id="T_d6661_level0_col3" class="col_heading level0 col3" >Intervention Length</th>
#       <th id="T_d6661_level0_col4" class="col_heading level0 col4" >Meta Pragmatic Information</th>
#       <th id="T_d6661_level0_col5" class="col_heading level0 col5" >Input</th>
#       <th id="T_d6661_level0_col6" class="col_heading level0 col6" >Input Enhancement</th>
#       <th id="T_d6661_level0_col7" class="col_heading level0 col7" >Inductive Consciousness-Raising</th>
#       <th id="T_d6661_level0_col8" class="col_heading level0 col8" >Deductive Consciousness-Raising</th>
#       <th id="T_d6661_level0_col9" class="col_heading level0 col9" >Production</th>
#       <th id="T_d6661_level0_col10" class="col_heading level0 col10" >Journal Writing/ Self-reflection</th>
#       <th id="T_d6661_level0_col11" class="col_heading level0 col11" >Feedback</th>
#       <th id="T_d6661_level0_col12" class="col_heading level0 col12" >Discussion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Study ID</th>
#       <th class="index_name level1" >Authors</th>
#       <th class="index_name level2" >Year</th>
#       <th class="index_name level3" >Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6661_level0_row0" class="row_heading level0 row0" rowspan="2">5.000000</th>
#       <th id="T_d6661_level1_row0" class="row_heading level1 row0" rowspan="2">Tateyama, Tateyama</th>
#       <th id="T_d6661_level2_row0" class="row_heading level2 row0" rowspan="2">1998, 2001</th>
#       <th id="T_d6661_level3_row0" class="row_heading level3 row0" >Explicit</th>
#       <td id="T_d6661_row0_col0" class="data row0 col0" >Novice</td>
#       <td id="T_d6661_row0_col1" class="data row0 col1" >No Impact, Negative</td>
#       <td id="T_d6661_row0_col2" class="data row0 col2" >Comprehension/Perception, Production</td>
#       <td id="T_d6661_row0_col3" class="data row0 col3" >Medium Treatments</td>
#       <td id="T_d6661_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_d6661_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_d6661_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_d6661_row0_col7" class="data row0 col7" >False</td>
#       <td id="T_d6661_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_d6661_row0_col9" class="data row0 col9" >True</td>
#       <td id="T_d6661_row0_col10" class="data row0 col10" >True</td>
#       <td id="T_d6661_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_d6661_row0_col12" class="data row0 col12" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d6661_level3_row1" class="row_heading level3 row1" >Implicit</th>
#       <td id="T_d6661_row1_col0" class="data row1 col0" >Novice</td>
#       <td id="T_d6661_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_d6661_row1_col2" class="data row1 col2" >Comprehension/Perception, Production</td>
#       <td id="T_d6661_row1_col3" class="data row1 col3" >Medium Treatments</td>
#       <td id="T_d6661_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_d6661_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_d6661_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_d6661_row1_col7" class="data row1 col7" >True</td>
#       <td id="T_d6661_row1_col8" class="data row1 col8" >False</td>
#       <td id="T_d6661_row1_col9" class="data row1 col9" >True</td>
#       <td id="T_d6661_row1_col10" class="data row1 col10" >True</td>
#       <td id="T_d6661_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_d6661_row1_col12" class="data row1 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d6661_level0_row2" class="row_heading level0 row2" rowspan="2">14.000000</th>
#       <th id="T_d6661_level1_row2" class="row_heading level1 row2" rowspan="2">Katayama</th>
#       <th id="T_d6661_level2_row2" class="row_heading level2 row2" rowspan="2">2012</th>
#       <th id="T_d6661_level3_row2" class="row_heading level3 row2" >Explicit</th>
#       <td id="T_d6661_row2_col0" class="data row2 col0" >Intermediate</td>
#       <td id="T_d6661_row2_col1" class="data row2 col1" >No Impact</td>
#       <td id="T_d6661_row2_col2" class="data row2 col2" >Production</td>
#       <td id="T_d6661_row2_col3" class="data row2 col3" >Short Treatments</td>
#       <td id="T_d6661_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_d6661_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_d6661_row2_col6" class="data row2 col6" >True</td>
#       <td id="T_d6661_row2_col7" class="data row2 col7" >False</td>
#       <td id="T_d6661_row2_col8" class="data row2 col8" >False</td>
#       <td id="T_d6661_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_d6661_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_d6661_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_d6661_row2_col12" class="data row2 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d6661_level3_row3" class="row_heading level3 row3" >Implicit</th>
#       <td id="T_d6661_row3_col0" class="data row3 col0" >Intermediate</td>
#       <td id="T_d6661_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_d6661_row3_col2" class="data row3 col2" >Production</td>
#       <td id="T_d6661_row3_col3" class="data row3 col3" >Short Treatments</td>
#       <td id="T_d6661_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_d6661_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_d6661_row3_col6" class="data row3 col6" >True</td>
#       <td id="T_d6661_row3_col7" class="data row3 col7" >True</td>
#       <td id="T_d6661_row3_col8" class="data row3 col8" >False</td>
#       <td id="T_d6661_row3_col9" class="data row3 col9" >False</td>
#       <td id="T_d6661_row3_col10" class="data row3 col10" >False</td>
#       <td id="T_d6661_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_d6661_row3_col12" class="data row3 col12" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ※ 片山は，short instruction をして，immediate posttest を実施している．一方で，tateyama は複数回の intervention を行い，別日に posttest を実行．
# これらのposttestの実施時期が影響...？
# つまり，片山は両群とも positive な結果になったが，immediate result だけでは？実際に，delayed posttest は点数が下がっており，定着はしていなさそう．
#
# → 念の為，どんなタスクを使って評価をしているか，詳しくみてみる

# %%
exp_vs_imp_study_id = [5.0, 14.0]

material_columns = [
    "Outcome Measure 1",
    "Outcome Measure 2",
    "Outcome Measure 3",
    "Outcome Measure 4"
]

df_between_res.loc[exp_vs_imp_study_id, ["Results", "Outcome Measures"] + material_columns]
# Out:
#                                                              Results  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit  No Impact, Negative
#                                        Implicit                  NaN
# 14.0     Katayama           2012       Explicit            No Impact
#                                        Implicit                  NaN
#
#                                                                      Outcome Measures  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit  Comprehension/Perception, Production
#                                        Implicit  Comprehension/Perception, Production
# 14.0     Katayama           2012       Explicit                            Production
#                                        Implicit                            Production
#
#                                                          Outcome Measure 1  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit      Multiple-Choice Tests
#                                        Implicit                        NaN
# 14.0     Katayama           2012       Explicit  Discourse Completion Task
#                                        Implicit                        NaN
#
#                                                 Outcome Measure 2  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit        Role-plays
#                                        Implicit               NaN
# 14.0     Katayama           2012       Explicit               NaN
#                                        Implicit               NaN
#
#                                                 Outcome Measure 3  \
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit               NaN
#                                        Implicit               NaN
# 14.0     Katayama           2012       Explicit               NaN
#                                        Implicit               NaN
#
#                                                 Outcome Measure 4
# Study ID Authors            Year       Group
# 5.0      Tateyama, Tateyama 1998, 2001 Explicit               NaN
#                                        Implicit               NaN
# 14.0     Katayama           2012       Explicit               NaN
#                                        Implicit               NaN

# %% [markdown]
# ※ Katayama は outcome measures に DCT を使用している．一般に，role-plays よりも簡単だと考えられるため（永遠に考えられる; writing なので，やり直しが容易），それも withing-group result の結果がでた理由...？
#
# ※ これらの結果を踏まえて，L2 Jp. を教えるうえで，explicit vs. implicit に差はないという結論を付けるには早い．
# 第一に，Tateyama はそもそも両群とも withing-group differences がない，つまり explicit, implicit の指導をしても，伸びがないという結果である．実際に，Taguchi (2015) でも指摘があるように，指導とテストにギャップがあるため，この結果からは explicit と implicit のどちらが良いかは言えない．
# 第二に，Katayama の study は 指導の直後に immediate posttest，12日後に delayed posttest を実施している．Delayed posttest のスコアは pretest のスコアより有意に高いものの，immediate posttest よりは低く，知識が定着したとは言えない結果であった．言い換えると，学習者は n desu/n desu ka に関する発達が起きておらず，practice effect が見られただけといえる．加えて，laboratory setting の研究で，介入期間も短い．そのため，教室での長期的な explicit/implicit の両指導が durable な L2 Jp. Pragmatic competence の発達に寄与するのか，より調査は必要だろう．
# また，Katayama の explicit instruction は implicit instruction を超えるにはシンプル過ぎたのかもしれない．Taguchi (2015) によると，meta-pragmatic instruction と production practice の combination が有効とされており，使用しながら気づきを得ることが有効なのかもしれない (cf., noticing hyp.)．

# %% [markdown]
# The following code block shows the explicit vs. explicit-expanded comparison results.

# %%
exp_vs_expexp_study_id = [6.0, 10.0, 13.0, 15.0]
exceptional_groups = [
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Control Fall"),
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Control Spring"),
    (15.0, "Iwai", "2010", "Control")
]

df_between_res.loc[exp_vs_expexp_study_id, "Participant":"Results"].drop(exceptional_groups)
# Out:
#                                                                                                                      Participant  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                     Mixed L1 Intermediate (n=22)
#                                                                        Explicit Expanded            Mixed L1 Intermediate (n=24)
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                     English L1 Novice (n=6)
#                                                                        Explicit Fall                      Mixed L1 Novice (n=14)
#                                                                        Explicit Spring                    Mixed L1 Novice (n=12)
# 13.0     Kim                                    2016                   Explicit Expanded  Mixed L1 Intermediate, Advanced (n=33)
#                                                                        Explicit           Mixed L1 Intermediate, Advanced (n=32)
# 15.0     Iwai                                   2010                   Explicit                   Not Specified L1 Novice (n=14)
#                                                                        Explicit Expanded          Not Specified L1 Novice (n=15)
#
#                                                                                               Target  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Speech Act
#                                                                        Explicit Expanded  Speech Act
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full        Particle
#                                                                        Explicit Fall        Particle
#                                                                        Explicit Spring      Particle
# 13.0     Kim                                    2016                   Explicit Expanded    Particle
#                                                                        Explicit             Particle
# 15.0     Iwai                                   2010                   Explicit           Small Talk
#                                                                        Explicit Expanded  Small Talk
#
#                                                                                                                            Outcome Measures  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Production, Production, Production, Comprehens...
#                                                                        Explicit Expanded  Production, Production, Production, Comprehens...
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                               Comprehension/Perception
#                                                                        Explicit Fall                               Comprehension/Perception
#                                                                        Explicit Spring                             Comprehension/Perception
# 13.0     Kim                                    2016                   Explicit Expanded                           Comprehension/Perception
#                                                                        Explicit                                    Comprehension/Perception
# 15.0     Iwai                                   2010                   Explicit                                                  Production
#                                                                        Explicit Expanded                                         Production
#
#                                                                                          Analysis  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit            Mixed+
#                                                                        Explicit Expanded   Mixed+
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full        Mixed
#                                                                        Explicit Fall        Mixed
#                                                                        Explicit Spring      Mixed
# 13.0     Kim                                    2016                   Explicit Expanded    Quan+
#                                                                        Explicit             Quan+
# 15.0     Iwai                                   2010                   Explicit             Mixed
#                                                                        Explicit Expanded    Mixed
#
#                                                                                                                              Results
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           No Impact, No Impact, No Impact, No Impact
#                                                                        Explicit Expanded                                         NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                                        Positive
#                                                                        Explicit Fall                                        Positive
#                                                                        Explicit Spring                                      Positive
# 13.0     Kim                                    2016                   Explicit Expanded                                   No Impact
#                                                                        Explicit                                                  NaN
# 15.0     Iwai                                   2010                   Explicit                                             Positive
#                                                                        Explicit Expanded                                    Positive

# %% [markdown]
# The table showed that half study showed expanded explicit groups outperformed regular groups, while half studies found no differences between expanded and regular explicit groups.
# Since each study has different definition of expanded explicit instruction, to compare them in more detailed manner, the following table lists the treatment features.
#
# 興味深いことに，統計的検定をした研究では，有意差がないとう結果になっている．そのため，Ishida や Iwai の study も統計的検定をしたら，差はでないのかもしれない．
# → 実際，ANOVA の交互作用は「伸び方に差がないか」をみているのに対して，形式の使用頻度やスコアの平均などを見るだけでは，事後テストの結果の比較になりがち．ここで興味があるのは，事前→事後での伸びが，expanded explicit の方が大きいかで，その意味では Ishida の結果はあまりないと思う（天井効果で，explicit full は伸びがそもそも小さい; ただし，explicit fall・spring で事前・事後テストが異なるため，explicit full の「完全な」指導前→指導後の伸びは比較できない）．
#
# → Iwai の場合は，例えば n desu の出現頻度を目的変数，時刻・group・時刻 x group を説明変数とする，ポアソン回帰を構築し，時刻 x group が有意な変数となるか見れば良い
# （時刻が有意 → instruction は n desu の使用回数を増やす; group が有意 → どちらかの群がより多くの/少ない n desu を使用; 時刻 x group が有意 → 群が n desu の使用頻度を調整; Frequency を見るに，group と 時刻 x group は有意な説明変数になるかも...？）
# ↔ Iwai の対象とする small talk は複合的な行為であるため，n desu の使用頻度に群間で有意な差があることがわかっても，small talk に差があることは言えない．

# %%
exp_vs_expexp_study_id = [6.0, 10.0, 13.0, 15.0]

exceptional_groups = [
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Control Fall"),
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Control Spring"),
    (15.0, "Iwai", "2010", "Control")
]

treatment_feature_columns = [
    "Intervention Length",
    "Meta Pragmatic Information",
    "Input",
    "Input Enhancement",
    "Inductive Consciousness-Raising",
    "Deductive Consciousness-Raising",
    "Production",
    "Journal Writing/ Self-reflection",
    "Feedback",
    "Discussion"
]

df_between_res.loc[
    exp_vs_expexp_study_id, 
    ["Proficiency Level", "Results", "Outcome Measures"] + treatment_feature_columns
].drop(
    exceptional_groups
).style.apply(
    lambda col: ["background-color: #d65f5f" if flag else "background-color: #5fba7d" for flag in col],
    subset=treatment_feature_columns[1:]
)
# Out:
# <style type="text/css">
# #T_1694e_row0_col4, #T_1694e_row0_col5, #T_1694e_row0_col7, #T_1694e_row0_col9, #T_1694e_row0_col10, #T_1694e_row0_col11, #T_1694e_row0_col12, #T_1694e_row1_col4, #T_1694e_row1_col5, #T_1694e_row1_col9, #T_1694e_row2_col4, #T_1694e_row2_col5, #T_1694e_row2_col7, #T_1694e_row2_col9, #T_1694e_row2_col12, #T_1694e_row3_col4, #T_1694e_row3_col9, #T_1694e_row3_col12, #T_1694e_row4_col4, #T_1694e_row4_col5, #T_1694e_row4_col7, #T_1694e_row4_col9, #T_1694e_row4_col12, #T_1694e_row5_col4, #T_1694e_row5_col5, #T_1694e_row5_col12, #T_1694e_row6_col4, #T_1694e_row6_col5, #T_1694e_row6_col12, #T_1694e_row7_col4, #T_1694e_row7_col5, #T_1694e_row7_col8, #T_1694e_row7_col11, #T_1694e_row7_col12, #T_1694e_row8_col4, #T_1694e_row8_col5, #T_1694e_row8_col8, #T_1694e_row8_col10, #T_1694e_row8_col11, #T_1694e_row8_col12 {
#   background-color: #d65f5f;
# }
# #T_1694e_row0_col6, #T_1694e_row0_col8, #T_1694e_row1_col6, #T_1694e_row1_col7, #T_1694e_row1_col8, #T_1694e_row1_col10, #T_1694e_row1_col11, #T_1694e_row1_col12, #T_1694e_row2_col6, #T_1694e_row2_col8, #T_1694e_row2_col10, #T_1694e_row2_col11, #T_1694e_row3_col5, #T_1694e_row3_col6, #T_1694e_row3_col7, #T_1694e_row3_col8, #T_1694e_row3_col10, #T_1694e_row3_col11, #T_1694e_row4_col6, #T_1694e_row4_col8, #T_1694e_row4_col10, #T_1694e_row4_col11, #T_1694e_row5_col6, #T_1694e_row5_col7, #T_1694e_row5_col8, #T_1694e_row5_col9, #T_1694e_row5_col10, #T_1694e_row5_col11, #T_1694e_row6_col6, #T_1694e_row6_col7, #T_1694e_row6_col8, #T_1694e_row6_col9, #T_1694e_row6_col10, #T_1694e_row6_col11, #T_1694e_row7_col6, #T_1694e_row7_col7, #T_1694e_row7_col9, #T_1694e_row7_col10, #T_1694e_row8_col6, #T_1694e_row8_col7, #T_1694e_row8_col9 {
#   background-color: #5fba7d;
# }
# </style>
# <table id="T_1694e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1694e_level0_col0" class="col_heading level0 col0" >Proficiency Level</th>
#       <th id="T_1694e_level0_col1" class="col_heading level0 col1" >Results</th>
#       <th id="T_1694e_level0_col2" class="col_heading level0 col2" >Outcome Measures</th>
#       <th id="T_1694e_level0_col3" class="col_heading level0 col3" >Intervention Length</th>
#       <th id="T_1694e_level0_col4" class="col_heading level0 col4" >Meta Pragmatic Information</th>
#       <th id="T_1694e_level0_col5" class="col_heading level0 col5" >Input</th>
#       <th id="T_1694e_level0_col6" class="col_heading level0 col6" >Input Enhancement</th>
#       <th id="T_1694e_level0_col7" class="col_heading level0 col7" >Inductive Consciousness-Raising</th>
#       <th id="T_1694e_level0_col8" class="col_heading level0 col8" >Deductive Consciousness-Raising</th>
#       <th id="T_1694e_level0_col9" class="col_heading level0 col9" >Production</th>
#       <th id="T_1694e_level0_col10" class="col_heading level0 col10" >Journal Writing/ Self-reflection</th>
#       <th id="T_1694e_level0_col11" class="col_heading level0 col11" >Feedback</th>
#       <th id="T_1694e_level0_col12" class="col_heading level0 col12" >Discussion</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Study ID</th>
#       <th class="index_name level1" >Authors</th>
#       <th class="index_name level2" >Year</th>
#       <th class="index_name level3" >Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1694e_level0_row0" class="row_heading level0 row0" rowspan="2">6.000000</th>
#       <th id="T_1694e_level1_row0" class="row_heading level1 row0" rowspan="2">Tateyama, Tateyama, Tateyama, Tateyama</th>
#       <th id="T_1694e_level2_row0" class="row_heading level2 row0" rowspan="2">2006, 2007, 2008, 2009</th>
#       <th id="T_1694e_level3_row0" class="row_heading level3 row0" >Explicit</th>
#       <td id="T_1694e_row0_col0" class="data row0 col0" >Intermediate</td>
#       <td id="T_1694e_row0_col1" class="data row0 col1" >No Impact, No Impact, No Impact, No Impact</td>
#       <td id="T_1694e_row0_col2" class="data row0 col2" >Production, Production, Production, Comprehension/Perception</td>
#       <td id="T_1694e_row0_col3" class="data row0 col3" >Medium Treatments</td>
#       <td id="T_1694e_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_1694e_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_1694e_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_1694e_row0_col7" class="data row0 col7" >True</td>
#       <td id="T_1694e_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_1694e_row0_col9" class="data row0 col9" >True</td>
#       <td id="T_1694e_row0_col10" class="data row0 col10" >True</td>
#       <td id="T_1694e_row0_col11" class="data row0 col11" >True</td>
#       <td id="T_1694e_row0_col12" class="data row0 col12" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1694e_level3_row1" class="row_heading level3 row1" >Explicit Expanded</th>
#       <td id="T_1694e_row1_col0" class="data row1 col0" >Intermediate</td>
#       <td id="T_1694e_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_1694e_row1_col2" class="data row1 col2" >Production, Production, Production, Comprehension/Perception</td>
#       <td id="T_1694e_row1_col3" class="data row1 col3" >Medium Treatments</td>
#       <td id="T_1694e_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_1694e_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_1694e_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_1694e_row1_col7" class="data row1 col7" >False</td>
#       <td id="T_1694e_row1_col8" class="data row1 col8" >False</td>
#       <td id="T_1694e_row1_col9" class="data row1 col9" >True</td>
#       <td id="T_1694e_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_1694e_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_1694e_row1_col12" class="data row1 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1694e_level0_row2" class="row_heading level0 row2" rowspan="3">10.000000</th>
#       <th id="T_1694e_level1_row2" class="row_heading level1 row2" rowspan="3">Ishida, Ishida, Ishida</th>
#       <th id="T_1694e_level2_row2" class="row_heading level2 row2" rowspan="3">2007, 2009, 2009</th>
#       <th id="T_1694e_level3_row2" class="row_heading level3 row2" >Explicit Full</th>
#       <td id="T_1694e_row2_col0" class="data row2 col0" >Novice</td>
#       <td id="T_1694e_row2_col1" class="data row2 col1" >Positive</td>
#       <td id="T_1694e_row2_col2" class="data row2 col2" >Comprehension/Perception</td>
#       <td id="T_1694e_row2_col3" class="data row2 col3" >Long Treatments</td>
#       <td id="T_1694e_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_1694e_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_1694e_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_1694e_row2_col7" class="data row2 col7" >True</td>
#       <td id="T_1694e_row2_col8" class="data row2 col8" >False</td>
#       <td id="T_1694e_row2_col9" class="data row2 col9" >True</td>
#       <td id="T_1694e_row2_col10" class="data row2 col10" >False</td>
#       <td id="T_1694e_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_1694e_row2_col12" class="data row2 col12" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1694e_level3_row3" class="row_heading level3 row3" >Explicit Fall</th>
#       <td id="T_1694e_row3_col0" class="data row3 col0" >Novice</td>
#       <td id="T_1694e_row3_col1" class="data row3 col1" >Positive</td>
#       <td id="T_1694

# %% [markdown]
# Iwai の 2群は，additional treatment と self-reflection の有無が regular vs. expanded の差．
# Kim は meta-pragmatic information の提示方法の質的な違いを比較．
# Ishida は，2学期連続で intervention をしており，explicit fall = explicit spring < explicit fall + spring の順番で，intervention の期間は長く，explicit fall < explicit spring = explicit fall の順番で，input/indective consciousness-raising の有無に差．
# Tateyama の2群は，additional activity の有無．
#
# 第一に，2群間に差があったとする Ishida, Iwai は novice learner を対象としている．Proficiency が低い場合は，単純に instruction が長かったり，self-reflection や inductive consciousness-raising がある方が伸びるのかも (or 効果が見やすいのかも)...？
# 一方で，Kim や Tateyama は質的な差が2群間にあることを報告している．
#
# もう少しフラットな目で見ると，
# 1. meta-pragmatic information の提示方法の差は結果に影響を与えない (cf., Kim)
# 2. Production 練習をしない場合，additional treatment (e.g., self-evaluation) の有無は，伸びの差に影響...？（Iwai, Tateyama）
# 3. Production 練習がある場合，activity の差よりかは，intervention の長さの方が重要かも...？（Ishida, Tateyama）
#
# 統計的検定がどのように行われたのか詳しくみるために，analysis の詳細な方法をみてみる

# %%
exp_vs_expexp_study_id = [6.0, 10.0, 13.0, 15.0]

exceptional_groups = [
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Control Fall"),
    (10.0, "Ishida, Ishida, Ishida", "2007, 2009, 2009", "Control Spring"),
    (15.0, "Iwai", "2010", "Control")
]

analysis_columns = [
    "Quantitative Report Type",
    "Outcome Measure 1",
    "Outcome Measure 2",
    "Outcome Measure 3",
    "Outcome Measure 4"
]

df_between_res.loc[
    exp_vs_expexp_study_id, 
    ["Results", "Outcome Measures"] + analysis_columns
].drop(
    exceptional_groups
)
# Out:
#                                                                                                                              Results  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           No Impact, No Impact, No Impact, No Impact
#                                                                        Explicit Expanded                                         NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                                        Positive
#                                                                        Explicit Fall                                        Positive
#                                                                        Explicit Spring                                      Positive
# 13.0     Kim                                    2016                   Explicit Expanded                                   No Impact
#                                                                        Explicit                                                  NaN
# 15.0     Iwai                                   2010                   Explicit                                             Positive
#                                                                        Explicit Expanded                                    Positive
#
#                                                                                                                            Outcome Measures  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Production, Production, Production, Comprehens...
#                                                                        Explicit Expanded  Production, Production, Production, Comprehens...
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                               Comprehension/Perception
#                                                                        Explicit Fall                               Comprehension/Perception
#                                                                        Explicit Spring                             Comprehension/Perception
# 13.0     Kim                                    2016                   Explicit Expanded                           Comprehension/Perception
#                                                                        Explicit                                    Comprehension/Perception
# 15.0     Iwai                                   2010                   Explicit                                                  Production
#                                                                        Explicit Expanded                                         Production
#
#                                                                                                                    Quantitative Report Type  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Frequency, Statistical Test, Descriptive Stati...
#                                                                        Explicit Expanded                                                NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                      Frequency, Descriptive Statistics
#                                                                        Explicit Fall                                                    NaN
#                                                                        Explicit Spring                                                  NaN
# 13.0     Kim                                    2016                   Explicit Expanded           Statistical Test, Descriptive Statistics
#                                                                        Explicit                                                         NaN
# 15.0     Iwai                                   2010                   Explicit                                                   Frequency
#                                                                        Explicit Expanded                                                NaN
#
#                                                                                                      Outcome Measure 1  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit              Discourse Completion Task
#                                                                        Explicit Expanded                           NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full            Acceptability Judgment
#                                                                        Explicit Fall                               NaN
#                                                                        Explicit Spring                             NaN
# 13.0     Kim                                    2016                   Explicit Expanded         Multiple-Choice Tests
#                                                                        Explicit                                    NaN
# 15.0     Iwai                                   2010                   Explicit           Oral Spontaneous Interaction
#                                                                        Explicit Expanded                           NaN
#
#                                                                                                        Outcome Measure 2  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Oral Discourse Completion Task
#                                                                        Explicit Expanded                             NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                                 NaN
#                                                                        Explicit Fall                                 NaN
#                                                                        Explicit Spring                               NaN
# 13.0     Kim                                    2016                   Explicit Expanded                             NaN
#                                                                        Explicit                                      NaN
# 15.0     Iwai                                   2010                   Explicit                                      NaN
#                                                                        Explicit Expanded                             NaN
#
#                                                                                          Outcome Measure 3  \
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit                 Role-plays
#                                                                        Explicit Expanded               NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                   NaN
#                                                                        Explicit Fall                   NaN
#                                                                        Explicit Spring                 NaN
# 13.0     Kim                                    2016                   Explicit Expanded               NaN
#                                                                        Explicit                        NaN
# 15.0     Iwai                                   2010                   Explicit                        NaN
#                                                                        Explicit Expanded               NaN
#
#                                                                                                Outcome Measure 4
# Study ID Authors                                Year                   Group
# 6.0      Tateyama, Tateyama, Tateyama, Tateyama 2006, 2007, 2008, 2009 Explicit           Acceptability Judgment
#                                                                        Explicit Expanded                     NaN
# 10.0     Ishida, Ishida, Ishida                 2007, 2009, 2009       Explicit Full                         NaN
#                                                                        Explicit Fall                         NaN
#                                                                        Explicit Spring                       NaN
# 13.0     Kim                                    2016                   Explicit Expanded                     NaN
#                                                                        Explicit                              NaN
# 15.0     Iwai                                   2010                   Explicit                              NaN
#                                                                        Explicit Expanded                     NaN

# %% [markdown]
# ---
#
# ## 2. Frequency Analysis

# %% [markdown]
# ### 2.1. Target Factors
#
# This subsection calculates frequency and proportion of learning targets.
